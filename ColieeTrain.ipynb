# %% [markdown]
# # CAPTAIN-COLIEE 2023 Notebook
#
# This notebook demonstrates the process of setting up the environment, extracting the dataset, and training a model for the CAPTAIN-COLIEE 2023 competition.
#
# The steps include:
# 1. Drive Mount
# 2. Changing the working directory to the dataset root.
# 3. Installing required libraries.
# 4. Running the training script.

# %%
# !ls CAPTAIN_dataset/
# Out:
# ls: cannot access 'CAPTAIN_dataset/': No such file or directory

# %% [markdown]
# ## Changing Directory
#
# This cell changes the current working directory to the root of the extracted dataset. This is necessary to run the training script located within the `src` directory. **Note**: The path here might need to be adjusted based on the exact name of the extracted directory.

# %%
# %cd /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023
# Out:
# /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023

# %% [markdown]
# ## Installing Requirements
#
# These cells install the necessary Python libraries for the project, including transformers, tokenizers, and other packages specified in the `requirements.txt` file.

# %%
# !pip install --upgrade transformers tokenizers

# %%
# !pip install -r requirements.txt --no-deps
# Out:
# ...
#   Using cached gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# ...
#   Using cached fugashi-1.5.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.3 kB)
# ...
#   Using cached mecab_python3-1.0.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached packaging-21.3-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached unidic-lite-1.0.8.tar.gz (47.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached transformers-4.3.2-py3-none-any.whl.metadata (36 kB)
# ...
#   Using cached xlwt-1.3.0-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached ipadic-1.0.0.tar.gz (13.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Using cached transformers-4.3.2-py3-none-any.whl (1.8 MB)
# ...

# %%
# !pip install pytorch-lightning

# %%
# !pip install sacremoses

# %%
# !ls
# Out:
# 'CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023 (2)_CURSOR.zip'	 sample_data
#  CAPTAIN_dataset

# %%
# %cd /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023
# Out:
# /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023

# %%
# !pip install --upgrade transformers tokenizers

# %%
# !pip install -r requirements.txt --no-deps
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 141.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 697.9/697.9 kB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.2/591.2 kB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.6 MB/s eta 0:00:00
# ...
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658817 sha256=64ba4c7cbcb089e57dbddb7ba3b8da1e57c8dd5258a1854166fdfab0b663941c
# ...

# %%
# !pip install pytorch-lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 44.9 MB/s eta 0:00:00
# ...

# %%
# !pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 21.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.3.2 requires tokenizers<0.11,>=0.10.1, but you have tokenizers 0.22.1 which is incompatible.
# sentence-transformers 5.1.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.3.2 which is incompatible.
# ...

# %%
# !python src/train_optimized.py \
  --data_dir /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023/data/COLIEE2025statute_data-English/data_en_topk_150_r02_r03/ \
  --model_name_or_path bert-base-uncased \
  --log_dir settings/bert-optimized/ \
  --max_epochs 3 \
  --batch_size 8 \
  --gpus 1 \
   --num_workers 2 \
  --max_seq_length 256
# Out:
# python3: can't open file '/content/src/train_optimized.py': [Errno 2] No such file or directory

# %%
pwd
# Out:
# '/content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023'

# %%
# %cd /content/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023/
# Out:
# [Errno 2] No such file or directory: '/content/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023/'
# /content

# %% [markdown]
# The model has been trained for 2 epochs.

# %%
# !python src/train_optimized.py \
  --data_dir /content/drive/MyDrive/CAPTAIN_dataset/CAPTAIN-COLIEE2023-CAPTAIN-COLIEE2023/data/COLIEE2025statute_data-English/data_en_topk_150_r02_r03/ \
  --model_name_or_path bert-base-uncased \
  --log_dir settings/bert-optimized/ \
  --max_epochs 2 \
  --batch_size 8 \
  --gpus 1 \
   --num_workers 2 \
  --max_seq_length 256
# Out:
# Seed set to 0
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing RelevantDocModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing RelevantDocModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RelevantDocModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
